# %% [markdown]
# # Situering
# - De eigenaar van een huishoudelijke zonnepaneelinstallatie zou graag continu een voorspelling hebben van de opbrengst van zijn panelen gedurende de komende uren om het eigen verbruik te optimaliseren: bij een verwachte hoge opbrengst kan hij dan bijv. beslissen om de wasmachine aan te zetten.
# - Hij beschikt over de meterstand per uur sedert ongeveer één jaar (solar.csv).
# - Daarnaast zijn ook de gegevens van de waarnemingen van het weer (weather.csv) en
# - de uren van zonsopgang en –ondergang in dezelfde periode periode (sunrise-sunset.xlsx).
#
# # Vraag
# - Stel een regressiemodel op om de opbrengst per uur te voorspellen.
# - Kies een optimaal regressiemodel door verschillende modellen uit te proberen en te vergelijken volgens de "best practices".
# - Kies als maatstaf de gemiddelde afwijking van de absolute waarde op uurbasis.

# %%
import sys
import sklearn
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Preparation and cleanup of solar data

# %%
def prepare_solar():
    solar = pd.read_csv('datasets/solar.csv')  
    print(solar.head(10))
    print('-------------')
    print(solar.tail(10))
    solar['datetime'] = pd.to_datetime(solar['timestamp'].str[0:19],format='%Y-%m-%d %H:%M:%S')      
    solar['datetime_tz'] = solar['datetime'].dt.tz_localize('Europe/Berlin',ambiguous='NaT')
    solar['datetime_utc'] = solar['datetime_tz'].dt.tz_convert('UTC')
    solar['date'] = solar['datetime_utc'].dt.date
    solar['hour'] = solar['datetime_utc'].dt.hour
    solar = solar[['date','hour','kwh']]
    solar.dropna(inplace=True)
    solar.drop_duplicates(inplace=True)
    # todo timediff en alles > 1u er uit. 
    return solar

solar = prepare_solar()
solar.info()
solar.head()
# Out:
#                        timestamp   kwh
# 0  2023-03-11 16:00:10.160454+01  0.54
# 1  2023-03-11 17:00:10.217795+01  1.02
# 2  2023-03-11 18:00:10.284064+01  1.17
# 3  2023-03-11 19:00:10.224836+01  1.18
# 4  2023-03-11 20:00:10.201847+01  1.18
# 5  2023-03-11 21:00:10.338166+01  1.18
# 6  2023-03-11 22:00:10.189411+01  1.18
# 7   2023-03-11 23:00:10.14459+01  1.18
# 8  2023-03-12 00:00:10.058642+01  1.18
# 9  2023-03-12 01:00:10.136006+01  1.18
# -------------
#                           timestamp        kwh
# 9695  2024-04-19 01:00:10.322579+02  2417.3321
# 9696  2024-04-19 02:00:10.339044+02  2417.3321
# 9697  2024-04-19 03:00:10.343655+02  2417.3321
# 9698  2024-04-19 04:00:10.507106+02  2417.3321
# 9699  2024-04-19 05:00:10.326829+02  2417.3321
# 9700  2024-04-19 06:00:10.326636+02  2417.3321
# 9701  2024-04-19 07:00:10.424826+02  2417.3321
# 9702  2024-04-19 08:00:10.360449+02  2417.3336
# 9703  2024-04-19 09:00:10.437154+02  2417.3701
# 9704  2024-04-19 10:00:10.748713+02  2417.4788
# <class 'pandas.DataFrame'>
# Index: 9340 entries, 0 to 9704
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    9340 non-null   object
#  1   hour    9340 non-null   float64
#  2   kwh     9340 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 291.9+ KB
#          date  hour   kwh
# 0  2023-03-11  15.0  0.54
# 1  2023-03-11  16.0  1.02
# 2  2023-03-11  17.0  1.17
# 3  2023-03-11  18.0  1.18
# 4  2023-03-11  19.0  1.18

# %% [markdown]
# ## Preparation and cleanup of weather data

# %%
def prepare_weather():
    weather = pd.read_csv("datasets/weather.csv")
    print(weather.head(10))
    weather = weather[['timestamp','temp','pressure','cloudiness','humidity_relative']]
    weather = weather.groupby(by=['timestamp']).mean().reset_index()
    weather['datetime'] = pd.to_datetime(weather['timestamp'],format='%Y-%m-%dT%H:%M:%S')
    weather['date'] = weather['datetime'].dt.date
    weather['hour'] = weather['datetime'].dt.hour   
    weather = weather[['date','hour','temp','pressure','cloudiness','humidity_relative']]
    # weather.dropna(inplace=True)
    weather.drop_duplicates(inplace=True)
    return weather

weather = prepare_weather()
weather.info()
weather.head(30)
# Out:
#                                       FID                    the_geom  code  \
# 0  synop_data.6418.2023-03-01 09:00:00+00  POINT (51.347375 3.201846)  6418
# 1  synop_data.6414.2023-03-01 09:00:00+00   POINT (50.90398 3.121692)  6414
# 2  synop_data.6407.2023-03-01 09:00:00+00  POINT (51.200341 2.887306)  6407
# 3  synop_data.6434.2023-03-01 09:00:00+00  POINT (50.980293 3.816003)  6434
# 4  synop_data.6434.2023-03-01 10:00:00+00  POINT (50.980293 3.816003)  6434
# 5  synop_data.6418.2023-03-01 10:00:00+00  POINT (51.347375 3.201846)  6418
# 6  synop_data.6414.2023-03-01 10:00:00+00   POINT (50.90398 3.121692)  6414
# 7  synop_data.6407.2023-03-01 10:00:00+00  POINT (51.200341 2.887306)  6407
# 8  synop_data.6414.2023-03-01 11:00:00+00   POINT (50.90398 3.121692)  6414
# 9  synop_data.6418.2023-03-01 11:00:00+00  POINT (51.347375 3.201846)  6418
#
#              timestamp  precip_quantity  precip_range  temp  temp_min  \
# 0  2023-03-01T09:00:00              NaN           NaN   4.9       NaN
# 1  2023-03-01T09:00:00              NaN           NaN   2.1       NaN
# 2  2023-03-01T09:00:00              NaN           NaN   3.3       NaN
# 3  2023-03-01T09:00:00              NaN           NaN   1.6       NaN
# 4  2023-03-01T10:00:00              NaN           NaN   3.0       NaN
# 5  2023-03-01T10:00:00              NaN           NaN   5.3       NaN
# 6  2023-03-01T10:00:00              NaN           NaN   3.5       NaN
# 7  2023-03-01T10:00:00              NaN           NaN   4.2       NaN
# 8  2023-03-01T11:00:00              NaN           NaN   4.4       NaN
# 9  2023-03-01T11:00:00              NaN           NaN   5.7       NaN
#
#    temp_max  temp_grass_min  ...  wind_speed_unit  wind_direction  \
# 0       NaN             NaN  ...                1            50.0
# 1       NaN             NaN  ...                1            44.7
# 2       NaN             NaN  ...                1            60.0
# 3       NaN           -10.0  ...                1            71.6
# 4       NaN             NaN  ...                1            56.0
# 5       NaN             NaN  ...                1            44.5
# 6       NaN             NaN  ...                1            48.1
# 7       NaN             NaN  ...                1            60.0
# 8       NaN             NaN  ...                1            59.4
# 9       NaN             NaN  ...                1            48.4
#
#    wind_peak_speed  humidity_relative  weather_current  pressure  \
# 0              9.4               54.3              NaN    1029.7
# 1              7.5               73.7              NaN    1029.3
# 2              7.0                NaN              NaN    1029.6
# 3              5.9               70.9              NaN    1029.4
# 4              7.6               60.8              NaN    1028.8
# 5              9.9               55.6              NaN    1029.6
# 6              8.6               66.3              NaN    1028.9
# 7              9.0                NaN              NaN    1029.3
# 8             10.0               59.9              NaN    1028.2
# 9              8.3               52.1              NaN    1029.1
#
#    pressure_station_level  sun_duration_24hours  short_wave_from_sky_24hours  \
# 0                  1028.0                   NaN                          NaN
# 1                  1025.9                   NaN                          NaN
# 2                  1029.0                   NaN                          NaN
# 3                  1027.3                   NaN                          NaN
# 4                  1026.7                   NaN                          NaN
# 5                  1027.9                   NaN                          NaN
# 6                  1025.5                   NaN                          NaN
# 7                  1028.6                   NaN                          NaN
# 8                  1024.8                   NaN                          NaN
# 9                  1027.4                   NaN                          NaN
#
#    cloudiness
# 0         0.0
# 1         NaN
# 2         1.0
# 3         NaN
# 4         NaN
# 5         0.0
# 6         NaN
# 7         1.0
# 8         NaN
# 9         0.0
#
# [10 rows x 21 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 9960 entries, 0 to 9959
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               9960 non-null   object
#  1   hour               9960 non-null   int32
#  2   temp               9960 non-null   float64
#  3   pressure           9960 non-null   float64
#  4   cloudiness         9960 non-null   float64
#  5   humidity_relative  9960 non-null   float64
# dtypes: float64(4), int32(1), object(1)
# memory usage: 428.1+ KB
#           date  hour   temp  pressure  cloudiness  humidity_relative
# 0   2023-03-01     9  2.975  1029.500         0.5          66.300000
# 1   2023-03-01    10  4.000  1029.150         0.5          60.900000
# 2   2023-03-01    11  4.800  1028.575         0.5          55.000000
# 3   2023-03-01    12  5.375  1028.100         0.5          53.166667
# 4   2023-03-01    13  5.900  1027.125         0.5          51.833333
# 5   2023-03-01    14  5.950  1026.350         0.5          53.400000
# 6   2023-03-01    15  5.975  1025.625         0.5          55.366667
# 7   2023-03-01    16  5.700  1025.075         0.5          57.466667
# 8   2023-03-01    17  5.300  1024.725         0.5          58.866667
# 9   2023-03-01    18  4.700  1024.825         0.5          58.800000
# 10  2023-03-01    19  4.000  1025.025         0.5          60.466667
# 11  2023-03-01    20  3.000  1025.000         0.5          63.500000
# 12  2023-03-01    21  2.700  1024.925         0.5          64.166667
# 13  2023-03-01    22  2.475  1024.725         0.5          64.600000
# 14  2023-03-01    23  1.750  1025.025         0.5          71.466667
# 15  2023-03-02     0  1.300  1024.975         0.5          71.166667
# 16  2023-03-02     1  1.000  1024.550         0.5          72.200000
# 17  2023-03-02     2  0.675  1024.050         0.5          73.600000
# 18  2023-03-02     3  0.775  1023.800         0.5          74.100000
# 19  2023-03-02     4  0.575  1023.725         0.5          76.833333
# 20  2023-03-02     5  0.525  1023.775         0.5          77.566667
# 21  2023-03-02     6  0.400  1023.725         0.5          80.333333
# 22  2023-03-02     7  0.225  1024.075         0.0          84.066667
# 23  2023-03-02     8  1.150  1024.075         0.0          83.633333
# 24  2023-03-02     9  2.325  1024.225         0.0          79.333333
# 25  2023-03-02    10  3.400  1023.975         0.0          74.566667
# 26  2023-03-02    11  4.625  1023.825         0.0          70.133333
# 27  2023-03-02    12  5.500  1023.800         0.0          65.433333
# 28  2023-03-02    13  6.600  1023.425         0.0          62.833333
# 29  2023-03-02    14  7.075  1022.975         0.0          59.233333

# %% [markdown]
# ## Preparation and cleanup of sunrise/sunset data

# %%
def prepare_sunrise_sunset():
    sunrise_sunset = pd.read_excel("datasets/sunrise-sunset.xlsx") 
    print(sunrise_sunset.head(10))
    sunrise_sunset.rename(columns={'datum':'date'}, inplace=True)
    sunrise_sunset['sunrise'] = [pd.Timestamp.combine(d,t) for d,t in zip(sunrise_sunset['date'],sunrise_sunset['Opkomst'])]
    sunrise_sunset['noon'] = [pd.Timestamp.combine(d,t) for d,t in zip(sunrise_sunset['date'],sunrise_sunset['Op ware middag'])]
    sunrise_sunset['sunset'] = [pd.Timestamp.combine(d,t) for d,t in zip(sunrise_sunset['date'],sunrise_sunset['Ondergang'])]
    sunrise_sunset['sunrise'] = sunrise_sunset['sunrise'].dt.tz_localize('Europe/Berlin',ambiguous='NaT')
    sunrise_sunset['sunrise'] = sunrise_sunset['sunrise'].dt.tz_convert('UTC')
    sunrise_sunset['sunset'] = sunrise_sunset['sunset'].dt.tz_localize('Europe/Berlin',ambiguous='NaT')
    sunrise_sunset['sunset'] = sunrise_sunset['sunset'].dt.tz_convert('UTC')
    sunrise_sunset['date'] = sunrise_sunset['date'].dt.date
    sunrise_sunset = sunrise_sunset[['date','sunrise','sunset']]
    return sunrise_sunset

sunrise_sunset = prepare_sunrise_sunset()
sunrise_sunset.info()
sunrise_sunset.head()
# Out:
#        datum   Opkomst Op ware middag Ondergang
# 0 2023-01-01  08:45:00       12:46:00  16:47:00
# 1 2023-01-02  08:45:00       12:46:00  16:48:00
# 2 2023-01-03  08:45:00       12:47:00  16:49:00
# 3 2023-01-04  08:44:00       12:47:00  16:51:00
# 4 2023-01-05  08:44:00       12:48:00  16:52:00
# 5 2023-01-06  08:44:00       12:48:00  16:53:00
# 6 2023-01-07  08:43:00       12:49:00  16:54:00
# 7 2023-01-08  08:43:00       12:49:00  16:56:00
# 8 2023-01-09  08:43:00       12:50:00  16:57:00
# 9 2023-01-10  08:42:00       12:50:00  16:58:00
# <class 'pandas.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     731 non-null    object
#  1   sunrise  731 non-null    datetime64[us, UTC]
#  2   sunset   731 non-null    datetime64[us, UTC]
# dtypes: datetime64[us, UTC](2), object(1)
# memory usage: 17.3+ KB
#          date                   sunrise                    sunset
# 0  2023-01-01 2023-01-01 07:45:00+00:00 2023-01-01 15:47:00+00:00
# 1  2023-01-02 2023-01-02 07:45:00+00:00 2023-01-02 15:48:00+00:00
# 2  2023-01-03 2023-01-03 07:45:00+00:00 2023-01-03 15:49:00+00:00
# 3  2023-01-04 2023-01-04 07:44:00+00:00 2023-01-04 15:51:00+00:00
# 4  2023-01-05 2023-01-05 07:44:00+00:00 2023-01-05 15:52:00+00:00

# %% [markdown]
# Combine solar and weather data in a single dataframe.

# %%
solar_weather = pd.merge(solar, weather, on=['date','hour'], how='inner')
solar_weather.info()
solar_weather.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9340 entries, 0 to 9339
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               9340 non-null   object
#  1   hour               9340 non-null   float64
#  2   kwh                9340 non-null   float64
#  3   temp               9340 non-null   float64
#  4   pressure           9340 non-null   float64
#  5   cloudiness         9340 non-null   float64
#  6   humidity_relative  9340 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 510.9+ KB
#          date  hour   kwh  temp  pressure  cloudiness  humidity_relative
# 0  2023-03-11  15.0  0.54  6.85  1012.025         6.0          54.833333
# 1  2023-03-11  16.0  1.02  6.30  1011.625         7.0          57.800000
# 2  2023-03-11  17.0  1.17  5.95  1011.500         7.0          60.366667
# 3  2023-03-11  18.0  1.18  5.25  1011.850         7.0          64.500000
# 4  2023-03-11  19.0  1.18  4.85  1011.650         7.0          68.633333

# %% [markdown]
# Now also combine this dataset with sunrise_sunset.

# %%
all = pd.merge(solar_weather,sunrise_sunset,how='left', on='date')
all.info()
all.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9340 entries, 0 to 9339
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               9340 non-null   object
#  1   hour               9340 non-null   float64
#  2   kwh                9340 non-null   float64
#  3   temp               9340 non-null   float64
#  4   pressure           9340 non-null   float64
#  5   cloudiness         9340 non-null   float64
#  6   humidity_relative  9340 non-null   float64
#  7   sunrise            9340 non-null   datetime64[us, UTC]
#  8   sunset             9340 non-null   datetime64[us, UTC]
# dtypes: datetime64[us, UTC](2), float64(6), object(1)
# memory usage: 656.8+ KB
#          date  hour   kwh  temp  pressure  cloudiness  humidity_relative  \
# 0  2023-03-11  15.0  0.54  6.85  1012.025         6.0          54.833333
# 1  2023-03-11  16.0  1.02  6.30  1011.625         7.0          57.800000
# 2  2023-03-11  17.0  1.17  5.95  1011.500         7.0          60.366667
# 3  2023-03-11  18.0  1.18  5.25  1011.850         7.0          64.500000
# 4  2023-03-11  19.0  1.18  4.85  1011.650         7.0          68.633333
#
#                     sunrise                    sunset
# 0 2023-03-11 06:06:00+00:00 2023-03-11 17:40:00+00:00
# 1 2023-03-11 06:06:00+00:00 2023-03-11 17:40:00+00:00
# 2 2023-03-11 06:06:00+00:00 2023-03-11 17:40:00+00:00
# 3 2023-03-11 06:06:00+00:00 2023-03-11 17:40:00+00:00
# 4 2023-03-11 06:06:00+00:00 2023-03-11 17:40:00+00:00

# %% [markdown]
# ## Feature Engineering
# Only keep following features:
# - dayinyear: number of the day in de year (1/1 = 1, 31/12 = 365)
# - sunrise_delta: hours after sunrise
# - sunset_delta: hours before sunset
# - temp
# - pressure
# - cloudiness
# - humidity
# - production (kW): yield of the current hour

# %%
def prepare_all(all):
    all['date'] = pd.to_datetime(all['date'])
    all['hour'] = all['hour'].astype('int')
    all['dayinyear'] = all['date'].dt.strftime('%j').astype(int)
    all['production'] = all['kwh'] - all['kwh'].shift(1)
    all['sunrise_delta'] = all['hour'] - all['sunrise'].dt.hour # uren na zonsopgang
    all['sunset_delta'] = all['sunset'].dt.hour - all['hour'] # uren voor zonsondergang
    return all[['dayinyear','sunrise_delta','sunset_delta','temp','pressure','cloudiness','humidity_relative','production']]

all_final = prepare_all(all)
all_final.info()
print(all_final.head(30))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9340 entries, 0 to 9339
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dayinyear          9340 non-null   int64
#  1   sunrise_delta      9340 non-null   int64
#  2   sunset_delta       9340 non-null   int64
#  3   temp               9340 non-null   float64
#  4   pressure           9340 non-null   float64
#  5   cloudiness         9340 non-null   float64
#  6   humidity_relative  9340 non-null   float64
#  7   production         9339 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 583.9 KB
#     dayinyear  sunrise_delta  sunset_delta    temp  pressure  cloudiness  \
# 0          70              9             2   6.850  1012.025         6.0
# 1          70             10             1   6.300  1011.625         7.0
# 2          70             11             0   5.950  1011.500         7.0
# 3          70             12            -1   5.250  1011.850         7.0
# 4          70             13            -2   4.850  1011.650         7.0
# 5          70             14            -3   4.900  1011.700         7.0
# 6          70             15            -4   4.700  1011.525         7.0
# 7          70             16            -5   4.825  1011.325         8.0
# 8          70             17            -6   4.700  1010.750         8.0
# 9          71             -6            17   4.525  1010.250         7.0
# 10         71             -5            16   4.300  1009.500         8.0
# 11         71             -4            15   4.150  1008.975         7.0
# 12         71             -3            14   4.250  1008.350         7.0
# 13         71             -2            13   4.325  1007.950         8.0
# 14         71             -1            12   4.900  1007.825         8.0
# 15         71              0            11   6.025  1008.000         8.0
# 16         71              1            10   7.725  1008.475         6.0
# 17         71              2             9   8.350  1009.000         7.0
# 18         71              3             8   9.300  1009.600         6.0
# 19         71              4             7   9.950  1009.975         5.0
# 20         71              5             6  10.725  1010.200         5.0
# 21         71              6             5  10.950  1010.100         6.0
# 22         71              7             4  11.075  1009.450         7.0
# 23         71              8             3  11.375  1009.500         6.0
# 24         71              9             2  10.575  1009.575         7.0
# 25         71             10             1  10.325  1009.350         8.0
# 26         71             11             0  10.350  1008.950         8.0
# 27         71             12            -1   9.800  1008.500         8.0
# 28         71             13            -2   9.475  1007.800         7.0
# 29         71             14            -3   9.850  1007.000         8.0
#
#     humidity_relative  production
# 0           54.833333         NaN
# 1           57.800000        0.48
# 2           60.366667        0.15
# 3           64.500000        0.01
# 4           68.633333        0.00
# 5           68.400000        0.00
# 6           69.600000        0.00
# 7           70.133333        0.00
# 8           70.400000        0.00
# 9           75.166667        0.00
# 10          80.400000        0.00
# 11          82.466667        0.00
# 12          86.666667        0.00
# 13          91.633333        0.00
# 14          95.200000        0.00
# 15          97.000000        0.00
# 16          96.566667        0.00
# 17          94.200000        0.09
# 18          90.433333        0.30
# 19          85.933333        0.66
# 20          82.133333        1.26
# 21          77.566667        0.82
# 22          75.666667        1.09
# 23          73.100000        0.89
# 24          75.966667        0.24
# 25          78.266667        0.08
# 26          80.133333        0.02
# 27          82.900000        0.00
# 28          85.466667        0.00
# 29          83.466667        0.00

# %% [markdown]
# Create a histogram for all numerical features

# %%
all_final.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'dayinyear'}>,
#         <Axes: title={'center': 'sunrise_delta'}>,
#         <Axes: title={'center': 'sunset_delta'}>],
#        [<Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'pressure'}>,
#         <Axes: title={'center': 'cloudiness'}>],
#        [<Axes: title={'center': 'humidity_relative'}>,
#         <Axes: title={'center': 'production'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Which column requires further attention? Declare the odd data en fix it.

# %%
all_final['production'].describe()
# Out:
# count    9339.000000
# mean        0.258801
# std        17.985281
# min     -1185.158200
# 25%         0.000000
# 50%         0.000000
# 75%         0.253200
# max      1269.965600
# Name: production, dtype: float64

# %%
all_final[(all_final['production'] < 0)   |   (all_final['production'] > 100)]
# Out:
#       dayinyear  sunrise_delta  sunset_delta    temp  pressure  cloudiness  \
# 3098        214             17            -2  16.200   988.850         8.0
# 3114        215              9             6  17.575  1005.675         7.0
#
#       humidity_relative  production
# 3098               93.5  -1185.1582
# 3114               81.3   1269.9656

# %%
all_final[(all_final['dayinyear'] >= 208)   &   (all_final['dayinyear'] <= 215)]
# Out:
#       dayinyear  sunrise_delta  sunset_delta    temp  pressure  cloudiness  \
# 3098        214             17            -2  16.200   988.850         8.0
# 3099        214             18            -3  16.875   990.050         7.0
# 3100        214             19            -4  17.000   991.550         7.0
# 3101        215             -4            19  17.125   992.600         7.0
# 3102        215             -3            18  16.925   993.250         8.0
# 3103        215             -2            17  16.850   994.050         8.0
# 3104        215             -1            16  16.325   994.800         8.0
# 3105        215              0            15  16.525   995.850         8.0
# 3106        215              1            14  16.125   997.025         8.0
# 3107        215              2            13  16.075   998.100         8.0
# 3108        215              3            12  16.350   999.300         7.5
# 3109        215              4            11  17.025  1000.600         7.0
# 3110        215              5            10  17.300  1001.700         7.5
# 3111        215              6             9  17.250  1002.825         7.5
# 3112        215              7             8  17.425  1003.775         7.5
# 3113        215              8             7  17.400  1004.650         7.5
# 3114        215              9             6  17.575  1005.675         7.0
# 3115        215             10             5  17.100  1006.775         7.5
# 3116        215             11             4  17.750  1007.525         7.0
# 3117        215             12             3  17.700  1008.075         7.5
# 3118        215             13             2  17.625  1008.475         7.5
# 3119        215             14             1  17.450  1009.125         7.0
# 3120        215             15             0  16.825  1009.650         3.0
# 3121        215             16            -1  15.450  1010.275         2.5
# 3122        215             17            -2  14.550  1011.000         6.0
# 3123        215             18            -3  14.150  1011.700         4.0
# 3124        215             19            -4  14.350  1012.125         7.0
#
#       humidity_relative  production
# 3098          93.500000  -1185.1582
# 3099          93.266667      0.0000
# 3100          92.900000      0.0000
# 3101          91.500000      0.0000
# 3102          89.866667      0.0000
# 3103          90.266667      0.0000
# 3104          91.333333      0.0000
# 3105          91.766667      0.0000
# 3106          92.933333      0.0000
# 3107          92.300000      0.0200
# 3108          89.100000      0.1000
# 3109          84.233333      0.2900
# 3110          78.066667      0.5700
# 3111          80.566667      0.8400
# 3112          80.300000      0.8000
# 3113          82.466667      0.4000
# 3114          81.300000   1269.9656
# 3115          84.366667      0.3624
# 3116          78.800000      0.5994
# 3117          75.400000      0.6324
# 3118          73.700000      0.2122
# 3119          73.133333      0.2263
# 3120          75.866667      0.0481
# 3121          83.633333      0.0000
# 3122          88.533333      0.0000
# 3123          89.466667      0.0000
# 3124          89.300000      0.0000

# %%
all_final_clean = all_final[(all_final['production'] > 0)   &   (all_final['production'] < 100)]

# %%
all_final_clean['production'].hist(bins=50)
# Out:
# <Axes: >

# %%
all_final_clean.describe()
# Out:
#          dayinyear  sunrise_delta  sunset_delta         temp     pressure  \
# count  4570.000000    4570.000000   4570.000000  4570.000000  4570.000000
# mean    169.668709       7.741794      5.135886    13.873386  1014.490673
# std      93.866190       3.950817      3.956721     5.835964    10.630352
# min       1.000000       1.000000     -5.000000    -4.150000   967.800000
# 25%      93.000000       4.000000      2.000000     9.625000  1009.306250
# 50%     158.000000       7.000000      5.000000    13.225000  1016.212500
# 75%     246.000000      11.000000      8.000000    18.350000  1021.600000
# max     365.000000      19.000000     15.000000    30.975000  1041.275000
#
#         cloudiness  humidity_relative   production
# count  4570.000000        4570.000000  4570.000000
# mean      5.240919          75.353414     0.510313
# std       2.388519          13.986130     0.752727
# min       0.000000          31.366667     0.000100
# 25%       3.000000          65.400000     0.077600
# 50%       6.000000          76.950000     0.266350
# 75%       7.000000          86.700000     0.799550
# max       8.000000          98.900000    36.194500

# %%
all_final_clean = all_final[(all_final['production'] >= 0)   &   (all_final['production'] <= 10)]

# %%
all_final_clean['production'].describe()
# Out:
# count    9336.000000
# mean        0.245923
# std         0.451651
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.252825
# max         2.098000
# Name: production, dtype: float64

# %% [markdown]
# Store the current dataframe to a csv file so we can use it later.

# %%
all_final_clean['production'].hist()
# Out:
# <Axes: >

# %%
all_final_clean.dropna(inplace=True)

# %%
all_final_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9336 entries, 1 to 9339
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dayinyear          9336 non-null   int64
#  1   sunrise_delta      9336 non-null   int64
#  2   sunset_delta       9336 non-null   int64
#  3   temp               9336 non-null   float64
#  4   pressure           9336 non-null   float64
#  5   cloudiness         9336 non-null   float64
#  6   humidity_relative  9336 non-null   float64
#  7   production         9336 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 656.4 KB

# %%
# 2. Define the period (L)
L = 365

# 3. Apply Sine and Cosine transformations
all_final_clean['day_sin'] = np.sin(2 * np.pi * all_final_clean['dayinyear'] / L)
all_final_clean['day_cos'] = np.cos(2 * np.pi * all_final_clean['dayinyear'] / L)

# %%
all_final = all_final_clean.copy()

# %%
all_final.drop(columns=['dayinyear'],inplace=True)

# %%
all_final.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9336 entries, 1 to 9339
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sunrise_delta      9336 non-null   int64
#  1   sunset_delta       9336 non-null   int64
#  2   temp               9336 non-null   float64
#  3   pressure           9336 non-null   float64
#  4   cloudiness         9336 non-null   float64
#  5   humidity_relative  9336 non-null   float64
#  6   production         9336 non-null   float64
#  7   day_sin            9336 non-null   float64
#  8   day_cos            9336 non-null   float64
# dtypes: float64(7), int64(2)
# memory usage: 729.4 KB

# %% [markdown]
# Split the dataset in a training and a testset

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(all_final, test_size=0.2, random_state=42)

# %% [markdown]
# Create a Random Forest model to predict the hourly production.
# - Create a pipeline with a StandardScaler and and a random forest regressor
# - Find the optimal parameter combination amongst
#   - bootstrap: False, True
#   - n_estimators: 50 - 200 with steps of 50
#   - max_depth: 10 - 50 with steps of 10

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

attribs =  train_set.drop('production',axis=1)
labels = train_set['production'].copy()

forest_reg = RandomForestRegressor(random_state=42)

param_grid = [
    {'randomforestregressor__bootstrap': [False, True], 
     'randomforestregressor__n_estimators': np.arange(50,200,50), 
     'randomforestregressor__max_depth': np.arange(10,50,10)},
]

pipeline = make_pipeline(StandardScaler(), forest_reg)

grid_search = GridSearchCV(pipeline, param_grid, cv=4,
                           scoring='neg_mean_absolute_error',
                           return_train_score=True,verbose=4,n_jobs=-1)
grid_search.fit(attribs, labels)

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# Fitting 4 folds for each of 24 candidates, totalling 96 fits
# {'randomforestregressor__bootstrap': True, 'randomforestregressor__max_depth': np.int64(20), 'randomforestregressor__n_estimators': np.int64(150)}
# -0.06279017521543669

# %% [markdown]
# Determine the mean absolute error on the test set. Is this a useful model?

# %%
from sklearn.metrics import mean_absolute_error

final_model= grid_search.best_estimator_

X_test = test_set.drop('production', axis=1)
y_test = test_set['production'].copy()

final_predictions = final_model.predict(X_test)

print(f'MAE = {round(mean_absolute_error(y_test, final_predictions),3)} kWh')
# Out:
# MAE = 0.06 kWh

# %%
# check for null in y_test and final_predictions
print(y_test.isnull().sum())
print(pd.Series(final_predictions).isnull().sum())
# Out:
# 0
# 0

# %%
# which elements in y_test are null
print(y_test[y_test.isnull()])
# Out:
# Series([], Name: production, dtype: float64)

# %%
y_test
# Out:
# 360     0.2604
# 9163    0.0000
# 5577    0.0048
# 7962    0.0000
# 7414    0.0000
#          ...
# 8642    0.0834
# 6676    0.1806
# 7496    0.6166
# 4953    0.0000
# 4634    0.0000
# Name: production, Length: 1868, dtype: float64

# %%
final_predictions
# Out:
# array([0.35430875, 0.        , 0.25542444, ..., 0.25542444, 0.        ,
#        0.        ], shape=(1868,))

# %%
best_rf = final_model.named_steps['randomforestregressor']

# %% [markdown]
# Explain the concept of noise in this context

# %% [markdown]
# We will never be able to predict the power consumption with 100 % accuracy because registrations might be erroneous and some factors are not concidered: shadows, dirt, ...

# %% [markdown]
# Store the model to a file.

# %%
import joblib

joblib.dump(final_model, "solar.pkl")
# Out:
# ['solar.pkl']
